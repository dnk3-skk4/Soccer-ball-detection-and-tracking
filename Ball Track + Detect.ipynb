# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from copy import deepcopy

# %%
# Perform updates on the python modules
# !pip install --user -q opencv-python
# !pip install --user -q numpy
# !pip install --user -q matplotlib

# %%
# version check, see if there are newer versions
print(cv2.__version__)
print(np.__version__)
print(mpl.__version__)
# Out:
# 4.2.0
# 1.18.2
# 3.1.1

# %%
# make sure the current directory is also where the folder the notebook resides in!
import os
os.getcwd()
# Out:
# 'C:\\Users\\gdioni\\Desktop\\Jupyter Notebook\\OpenCV'

# %% [markdown]
# # Image Processing Events

# %% [markdown]
# ## Tracking

# %%
def Set_Tracker(t_type_lst: list, t_type_index : int):
  # get the tracker list and get the current index
  tracker_name = t_type_lst[t_type_index]
  # Tracker creation
  tracker = None
  if tracker_name == t_type_lst[0]: 
    # BOOSTING
    tracker = cv2.TrackerBoosting_create()
  elif tracker_name == t_type_lst[1]:
    # MIL
    tracker = cv2.TrackerMIL_create()
  elif tracker_name == t_type_lst[2]:
    # KCF
    tracker = cv2.TrackerKCF_create()
  elif tracker_name == t_type_lst[3]:
    # TLD
    tracker = cv2.TrackerTLD_create()
  elif tracker_name == t_type_lst[4]:
    # MEDIANFLOW
    tracker = cv2.TrackerMedianFlow_create()
  elif tracker_name == t_type_lst[5]:
    # GOTURN
    tracker = cv2.TrackerGOTURN_create()
  elif tracker_name == t_type_lst[6]:
    # CSRT
    tracker = cv2.TrackerCSRT_create()
  elif tracker_name == t_type_lst[7]:
    tracker = cv2.TrackerMOSSE_create()
  else:
    print('Something went wrong initializing the tracker')
  return tracker
def Track_Object(dframe : np.array, tracker : 'tracker')->np.array:
  global ball_tracker_bbox, thickness, ball_bbox_upscale, downscale_size

  tracked, ball_tracker_bbox = tracker.update(dframe)
  FLAG_TRACKER_OK = tracked
  if not tracked:
    ball_tracker_bbox =  (-1,-1,-1,-1)
  return dframe

# %% [markdown]
# ## Detection using YOLOv3

# %% [markdown]
# ### Detection Helper Methods

# %%
# Get the names of the output layers
def getOutputsNames(net):
    # Get the names of all the layers in the network
    layersNames = net.getLayerNames()
    # Get the names of the output layers, i.e. the layers with unconnected outputs
    return [layersNames[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# Draw the predicted bounding box
def drawPred(frame, classId, conf, left, top, width, height):
    global bbox_detector_color, thickness

    # Draw a bounding box.
    cv2.rectangle(frame, (left, top), (left+width, top+height), bbox_detector_color, thickness, cv2.LINE_AA)
    label = '%.2f' % conf
        
    # Get the label for the class name and its confidence
    if classes:
        assert(classId < len(classes))
        label = '%s:%s' % (classes[classId], label)
        
    #Display the label at the top of the bounding box
    # labelSize, baseLine = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.5, 1)
    # top = max(top, labelSize[1])
    # cv2.rectangle(frame, (left, top - round(1.5*labelSize[1])), (left + round(1.5*labelSize[0]), top + baseLine), (255, 255, 255), cv2.FILLED)
    # cv2.putText(frame, label, (left, top), cv2.FONT_HERSHEY_SIMPLEX, 0.75, (0,0,0), 1)
    return

# Remove the bounding boxes with low confidence using non-maxima suppression
def postprocess(frame, outs):
    global ball_detector_bbox, FLAG_DETECT_OK
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]

    classIds = []
    confidences = []
    boxes = []
    # Scan through all the bounding boxes output from the network and keep only the
    # ones with high confidence scores. Assign the box's class label as the class with the highest score.
    classIds = []
    confidences = []
    boxes = []
    for out in outs:
        for detection in out:
            if detection[4] > objectnessThreshold :
                scores = detection[5:]
                classId = np.argmax(scores)
                confidence = scores[classId]
                if confidence > confThreshold and classId == 32:
                    # 'classId == 32' are sports ball objects
                    # only interested in detected sports ball objects
                    center_x = int(detection[0] * frameWidth)
                    center_y = int(detection[1] * frameHeight)
                    width = int(detection[2] * frameWidth)
                    height = int(detection[3] * frameHeight)
                    left = int(center_x - width / 2)
                    top = int(center_y - height / 2)
                    classIds.append(classId)
                    confidences.append(float(confidence))
                    boxes.append([left, top, width, height])

    # Perform non maximum suppression to eliminate redundant overlapping boxes with
    # lower confidences.
    indices = cv2.dnn.NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)
#     print('number of indices: ' + str(len(indices)))
    
    if len(indices) <= 0:
      ball_boxes_bb = (-1,-1,-1,-1)
      FLAG_DETECT_OK = False
      return
    # bounding boxes for detection
    for i in indices:
        i = i[0]
        box = boxes[i]
        left = box[0]
        top = box[1]
        width = box[2]
        height = box[3]
        
        # get the bounding box
        ball_detector_bbox = (left, top, width, height)
    FLAG_DETECT_OK = True
    return
    
def Detect_Object(frame: np.array):
  # Create a 4D blob from a frame.
  blob = cv2.dnn.blobFromImage(frame, 1/255, (inpWidth, inpHeight), [0,0,0], 1, crop=False)

  # Sets the input to the network
  net.setInput(blob)

  # Runs the forward pass to get output of the output layers
  outs = net.forward(getOutputsNames(net))
  #outs = net.forward()

  # Remove the bounding boxes with low confidence
  postprocess(frame, outs)
  return frame

# %% [markdown]
# # Keyboard Events

# %%
def EventKeyR_iniReset():
  global ini_frame_copy, ini_frame
  ini_frame = np.copy(ini_frame_copy)
  ini_flag = False
  return
def EventKeyEnter_ini():
  global ini_flag
  ini_flag = True
  return

# %% [markdown]
# # Trackbar Events

# %%
def EventTrkChangeTrackerType(*args):
  '''
  Changes t_type_index to the value from the trackbar 
  '''
  global t_type_index, FLAG_CHANGE_TRACKER
  t_type_index = args[0]
  FLAG_CHANGE_TRACKER = True
  return

# %% [markdown]
# # HELPER METHOD

# %%
def ValidateTracker(tracker_bb:tuple, detector_bb:tuple, tracker: 'Tracker object', frame) -> tuple:
  '''
  If the tracker's center point goes beyond the detector's rectangle
  set the tracker to the detector's bounding box
  '''
  global t_type_index, t_type_lst
  print('tracker: ' + str(tracker_bb))
  print('detector: ' + str(detector_bb))
  t0, t1, tw, th = tracker_bb
  d0, d1, dw, dh = detector_bb
  
  if sum([d0, d1, dw, dh]) <= 0:
    return tracker, tracker_bb
#   t0, t1, tw, th = tracker_bb
#   d0, d1, dw, dh = detector_bb

  # get tracker center
  x, y = t0+(tw//2), t1+(th//2)

  # get detector left, top, right, bottom coordinates
  x1, y1, x2, y2 = d0, d1, d0+dw, d1+dh
  valid = PointInsideRectange(x1,y1,x2,y2, x, y)
  row, col, dim = frame.shape
  d0, d1, dw, dh = int(max(0, d0)), int(max(0, d1)), int(max(0, dw)), int(max(0, dh))
  if not valid and (0 <= d0 and 0 <= dw and d0 + dw <= col and 0 <= d1 and 0 <= dh and d1 + dh <= row):
    '''
    if the tracker went outside the detector rectangle and detector_bb won't cause initialization issues
    '''
    print(d0 > 0, d1 > 0, d0+dw > 0, d1+dh > 0)
    tracker = Set_Tracker(t_type_lst, t_type_index)
    _ = tracker.init(frame_downscale, (d0, d1, dw, dh))
  elif not valid:
    '''
    if the tracker was invalid but the detector_bb will cause an issue
    simply invalidate the current tracker_bb and wait later
    '''
    tracker_bb = (-1,-1,-1,-1)
  return tracker, tracker_bb


def PointInsideRectange(x1, y1, x2, y2, x, y) -> bool:
  if x > x1 and x < x2 and y > y1 and y < y2:
    return True
  else:
    return False

# %% [markdown]
# # Main Method

# %%
# insert the video path here for ball tracking
path_vid = '.\soccer-ball.mp4'
cap = cv2.VideoCapture(path_vid)

'''
+++ TRACKER configuration
'''
win_name = 'Tracker'
ini_win_name = 'Select object bounding box'
t_type_lst = ['BOOSTING', 'MIL','KCF', 'TLD', 'MEDIANFLOW', 'GOTURN', 'CSRT', 'MOSSE']
t_type_index = 0 # used to change tracker type
t_type_text = t_type_lst[t_type_index]
t_type_min, t_type_max = 0, len(t_type_lst)-1
txt_font_size, txt_thickness = 2, 3

k = 0 # used for key press
k_timer = 1 # wait time for keyboard press
frame_counter = 0 # used for resetting the frame

cv2.namedWindow(win_name, cv2.WINDOW_AUTOSIZE)

# Bounding box
ball_detector_bbox = (-1, -1, -1, -1) # bounding box of Detector
ball_tracker_bbox = (-1, -1, -1, -1) # bounding box of Tracker

bbox_tracker_color = (255, 125, 0)
bbox_detector_color = (125, 255, 0)
FLAG_CHANGE_TRACKER = False
FLAG_TRACKER_OK = False
FLAG_DETECT_OK = False # Flag to use if ball was detected
detection_timer = 10 # Detect every Nth frame
thickness = 2
FLAG_INIT = False
downscale_size = 0.75
tracker = None
no_detect = 0

'''
--- TRACKER configurations
'''

'''
+++ YOLO v3 detector variables
'''
# Initialize the parameters
objectnessThreshold = 0.5 # Objectness threshold
confThreshold = 0.5       # Confidence threshold
nmsThreshold = 0.4        # Non-maximum suppression threshold
inpWidth = 416            # Width of network's input image
inpHeight = 416           # Height of network's input image

y3_weights_path = './data/yolov3.weights'
y3_config_path = './data/yolov3.cfg'
coco_classes_path = './data/coco.names' # file with multiple classes
ball_classes_path = './data/target.names' # only sports ball
choice_path = coco_classes_path
classes = None
with open(choice_path, 'rt') as f:
  classes = f.read().strip('\n').split('\n')

# load the network
net = cv2.dnn.readNetFromDarknet(y3_config_path, y3_weights_path)
# net = cv2.dnn.DNN_TARGET_OPENCL(y3_config_path, y3_weights_path)

'''
--- YOLO v3 Configuration
'''

if not cap.isOpened():
  print('Could not open the video')
else:
  cv2.createTrackbar('Trackers: ', win_name, t_type_min, t_type_max, EventTrkChangeTrackerType)
  while cap.isOpened() and k != 27:

    if k == ord('r'):
      '''
      When the 'r' keyboard button is pressed, reset the video
      '''
      # reset frame to position 0
      frame_counter = 0
      cap.set(cv2.CAP_PROP_POS_FRAMES, frame_counter)

    # read the frame  
    frameIsRead, f = cap.read()

    if not frameIsRead:
      print('Video read unsuccessful')
      break

    # keep track of frame tick
    frame_counter += 1
    # Attempt to down scale for FPS Boost
    row, col, dim = f.shape
    row, col = int(row*downscale_size), int(col*downscale_size)
    dim = (col, row)
    frame_downscale = cv2.resize(f, dim, interpolation = cv2.INTER_AREA)
    if not FLAG_INIT:
      ball_tracker_bbox = cv2.selectROI(ini_win_name, frame_downscale)
      tracker = Set_Tracker(t_type_lst, t_type_index)
      FLAG_INIT = tracker.init(frame_downscale, ball_tracker_bbox)
      if FLAG_INIT:
        print('Tracker Initialized')
      else:
        print('Tracker not initialized')
      cv2.destroyWindow(ini_win_name)
    
    # perform detection every Nth frames
    ball_detector_bbox = (-1, -1, -1, -1)
    if (frame_counter - 1) % detection_timer == 0:
      # ball_detector_bbox gets updated inside Detect_Object
      detect_frame = Detect_Object(frame_downscale)
      if not FLAG_DETECT_OK:
        no_detect += 1
      else:
        no_detect = 0

    # ball_tracker_bbox gets updated inside Track_Objects
    track_frame = Track_Object(frame_downscale, tracker)

    tracker, ball_tracker_bbox = ValidateTracker(ball_tracker_bbox, ball_detector_bbox, tracker, frame_downscale)
    t0, t1, t2, t3 = ball_tracker_bbox
    d0, d1, d2, d3 = ball_detector_bbox

    print('Detector: ' + str(sum(ball_detector_bbox)))
    print('Tracker: ' + str(sum(ball_tracker_bbox)))
    print('\n')
    if sum(ball_detector_bbox) >= 0:
      cv2.rectangle(frame_downscale, (int(d0), int(d1)), (int(d0+d2), int(d1+d3)), bbox_detector_color, thickness, cv2.LINE_AA)
    if sum(ball_tracker_bbox) >= 0 and no_detect < 2:
      cv2.rectangle(frame_downscale, (int(t0), int(t1)), (int(t0+t2), int(t1+t3)), bbox_tracker_color, thickness, cv2.LINE_AA)
      cv2.putText(frame_downscale, 'Tracker: ' + str(tracker),(10,row), cv2.FONT_HERSHEY_PLAIN, txt_font_size, (255, 255, 255), txt_thickness, cv2.LINE_AA)
    else:
      cv2.putText(frame_downscale, 'No object tracked',(10,row), cv2.FONT_HERSHEY_PLAIN, txt_font_size, (255, 255, 255), txt_thickness, cv2.LINE_AA)
    cv2.imshow(win_name, frame_downscale)
    
    # read keyboard input
    k = cv2.waitKey(k_timer)

# release of the cap object
cap.release()
# close all windows
cv2.destroyAllWindows()
# Out:
# Tracker Initialized
# tracker: (407.0, 225.0, 105.0, 98.0)
# detector: (427, 242, 80, 75)
# Detector: 824
# Tracker: 835.0
#
#
# tracker: (407.0, 222.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 832.0
#
#
# tracker: (406.0, 222.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 831.0
#
#
# tracker: (406.0, 221.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 830.0
#
#
# tracker: (405.0, 223.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 831.0
#
#
# tracker: (402.0, 224.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 829.0
#
#
# tracker: (401.0, 224.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 828.0
#
#
# tracker: (397.0, 223.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 823.0
#
#
# tracker: (398.0, 224.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 825.0
#
#
# tracker: (395.0, 224.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 822.0
#
#
# tracker: (395.0, 227.0, 105.0, 98.0)
# detector: (409, 247, 83, 78)
# Detector: 817
# Tracker: 825.0
#
#
# tracker: (392.0, 230.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 825.0
#
#
# tracker: (390.0, 232.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 825.0
#
#
# tracker: (387.0, 233.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 823.0
#
#
# tracker: (387.0, 233.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 823.0
#
#
# tracker: (383.0, 236.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 822.0
#
#
# tracker: (381.0, 235.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 819.0
#
#
# tracker: (379.0, 238.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 820.0
#
#
# tracker: (377.0, 238.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 818.0
#
#
# tracker: (376.0, 240.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 819.0
#
#
# tracker: (372.0, 238.0, 105.0, 98.0)
# detector: (384, 254, 97, 90)
# Detector: 825
# Tracker: 813.0
#
#
# tracker: (370.0, 239.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 812.0
#
#
# tracker: (368.0, 237.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 808.0
#
#
# tracker: (372.0, 238.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 813.0
#
#
# tracker: (371.0, 238.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 812.0
#
#
# tracker: (374.0, 234.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 811.0
#
#
# tracker: (373.0, 232.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 808.0
#
#
# tracker: (375.0, 234.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 812.0
#
#
# tracker: (372.0, 234.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 809.0
#
#
# tracker: (389.0, 238.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 830.0
#
#
# tracker: (419.0, 233.0, 105.0, 98.0)
# detector: (425, 253, 70, 93)
# Detector: 841
# Tracker: 855.0
#
#
# tracker: (385.0, 236.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 824.0
#
#
# tracker: (386.0, 242.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 831.0
#
#
# tracker: (390.0, 245.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 838.0
#
#
# tracker: (391.0, 246.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 840.0
#
#
# tracker: (395.0, 248.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 846.0
#
#
# tracker: (401.0, 251.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 855.0
#
#
# tracker: (407.0, 255.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 865.0
#
#
# tracker: (413.0, 259.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 875.0
#
#
# tracker: (418.0, 263.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 884.0
#
#
# tracker: (423.0, 265.0, 105.0, 98.0)
# detector: (426, 278, 117, 109)
# Detector: 930
# Tracker: 891.0
#
#
# tracker: (431.0, 266.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 900.0
#
#
# tracker: (437.0, 268.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 908.0
#
#
# tracker: (444.0, 270.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 917.0
#
#
# tracker: (451.0, 273.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 927.0
#
#
# tracker: (462.0, 276.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 941.0
#
#
# tracker: (472.0, 278.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 953.0
#
#
# tracker: (479.0, 279.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 961.0
#
#
# tracker: (489.0, 280.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 972.0
#
#
# tracker: (496.0, 282.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 981.0
#
#
# tracker: (503.0, 286.0, 105.0, 98.0)
# detector: (514, 309, 114, 102)
# Detector: 1039
# Tracker: 992.0
#
#
# tracker: (509.0, 292.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1004.0
#
#
# tracker: (510.0, 296.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1009.0
#
#
# tracker: (508.0, 298.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1009.0
#
#
# tracker: (504.0, 300.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1007.0
#
#
# tracker: (500.0, 303.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1006.0
#
#
# tracker: (493.0, 306.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1002.0
#
#
# tracker: (484.0, 307.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 994.0
#
#
# tracker: (479.0, 305.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 987.0
#
#
# tracker: (473.0, 306.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 982.0
#
#
# tracker: (467.0, 308.0, 105.0, 98.0)
# detector: (476, 329, 118, 110)
# Detector: 1033
# Tracker: 978.0
#
#
# tracker: (460.0, 311.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 974.0
#
#
# tracker: (449.0, 314.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 966.0
#
#
# tracker: (481.0, 319.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1003.0
#
#
# tracker: (439.0, 279.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 921.0
#
#
# tracker: (469.0, 317.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 989.0
#
#
# tracker: (466.0, 319.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 988.0
#
#
# tracker: (466.0, 325.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 994.0
#
#
# tracker: (476.0, 333.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1012.0
#
#
# tracker: (477.0, 342.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1022.0
#
#
# tracker: (474.0, 354.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1031.0
#
#
# tracker: (516.0, 365.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1084.0
#
#
# tracker: (533.0, 355.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1091.0
#
#
# tracker: (558.0, 346.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1107.0
#
#
# tracker: (539.0, 320.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1062.0
#
#
# tracker: (576.0, 320.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1099.0
#
#
# tracker: (611.0, 316.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1130.0
#
#
# tracker: (601.0, 300.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1104.0
#
#
# tracker: (602.0, 293.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1098.0
#
#
# tracker: (575.0, 285.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1063.0
#
#
# tracker: (596.0, 288.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1087.0
#
#
# tracker: (612.0, 290.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1105.0
#
#
# tracker: (627.0, 294.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1124.0
#
#
# tracker: (641.0, 296.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1140.0
#
#
# tracker: (655.0, 305.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1163.0
#
#
# tracker: (697.0, 311.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1211.0
#
#
# tracker: (716.0, 306.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1225.0
# tracker: (737.0, 295.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1235.0
#
#
# tracker: (695.0, 255.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1153.0
#
#
# tracker: (729.0, 259.0, 105.0, 98.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1191.0
#
#
# tracker: (750.0, 246.0, 105.0, 98.0)
# detector: (107, 224, 115, 105)
# True True True True
# Detector: 551
# Tracker: 1199.0
#
#
# tracker: (91.0, 224.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 535.0
#
#
# tracker: (76.0, 222.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 518.0
#
#
# tracker: (60.0, 217.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 497.0
#
#
# tracker: (45.0, 213.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 478.0
#
#
# tracker: (32.0, 212.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 464.0
#
#
# tracker: (20.0, 210.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 450.0
#
#
# tracker: (9.0, 209.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 438.0
#
#
# tracker: (0.0, 210.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 430.0
#
#
# tracker: (1.0, 192.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 413.0
#
#
# tracker: (0.0, 191.0, 115.0, 105.0)
# detector: (-5, 200, 96, 106)
# Detector: 397
# Tracker: 411.0
#
#
# tracker: (0.0, 188.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 408.0
#
#
# tracker: (0.0, 188.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 408.0
#
#
# tracker: (0.0, 189.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 409.0
#
#
# tracker: (0.0, 189.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 409.0
#
#
# tracker: (0.0, 195.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 415.0
#
#
# tracker: (0.0, 191.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 411.0
#
#
# tracker: (0.0, 186.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 406.0
#
#
# tracker: (0.0, 185.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 405.0
#
#
# tracker: (0.0, 179.0, 115.0, 105.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 399.0
#
#
# tracker: (0.0, 178.0, 115.0, 105.0)
# detector: (0, 179, 37, 110)
# False True True True
# Detector: 326
# Tracker: 398.0
#
#
# tracker: (0.0, 179.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 326.0
#
#
# tracker: (0.0, 181.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 328.0
#
#
# tracker: (0.0, 189.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 336.0
#
#
# tracker: (0.0, 194.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 341.0
#
#
# tracker: (0.0, 199.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 346.0
#
#
# tracker: (0.0, 207.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 354.0
#
#
# tracker: (4.0, 215.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 366.0
#
#
# tracker: (9.0, 224.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 380.0
#
#
# tracker: (14.0, 230.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 391.0
#
#
# tracker: (20.0, 238.0, 37.0, 110.0)
# detector: (-1, 233, 55, 101)
# Detector: 388
# Tracker: 405.0
#
#
# tracker: (23.0, 243.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 413.0
#
#
# tracker: (8.0, 267.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 422.0
#
#
# tracker: (17.0, 278.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 442.0
#
#
# tracker: (27.0, 285.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 459.0
#
#
# tracker: (35.0, 293.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 475.0
#
#
# tracker: (46.0, 301.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 494.0
#
#
# tracker: (60.0, 303.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 510.0
#
#
# tracker: (74.0, 309.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 530.0
#
#
# tracker: (85.0, 312.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 544.0
#
#
# tracker: (99.0, 317.0, 37.0, 110.0)
# detector: (72, 308, 106, 93)
# Detector: 579
# Tracker: 563.0
#
#
# tracker: (113.0, 322.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 582.0
#
#
# tracker: (127.0, 325.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 599.0
#
#
# tracker: (139.0, 327.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 613.0
#
#
# tracker: (153.0, 330.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 630.0
#
#
# tracker: (167.0, 332.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 646.0
#
#
# tracker: (172.0, 330.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 649.0
#
#
# tracker: (186.0, 332.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 665.0
#
#
# tracker: (200.0, 330.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 677.0
#
#
# tracker: (212.0, 329.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 688.0
#
#
# tracker: (223.0, 322.0, 37.0, 110.0)
# detector: (216, 318, 101, 104)
# Detector: 739
# Tracker: 692.0
#
#
# tracker: (237.0, 319.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 703.0
#
#
# tracker: (251.0, 318.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 716.0
#
#
# tracker: (261.0, 307.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 715.0
#
#
# tracker: (275.0, 304.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 726.0
#
#
# tracker: (289.0, 304.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 740.0
#
#
# tracker: (303.0, 304.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 754.0
#
#
# tracker: (317.0, 306.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 770.0
#
#
# tracker: (331.0, 310.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 788.0
#
#
# tracker: (342.0, 308.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 797.0
#
#
# tracker: (356.0, 313.0, 37.0, 110.0)
# detector: (346, 308, 112, 97)
# Detector: 863
# Tracker: 816.0
#
#
# tracker: (361.0, 309.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 817.0
#
#
# tracker: (373.0, 310.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 830.0
#
#
# tracker: (377.0, 312.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 836.0
#
#
# tracker: (390.0, 320.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 857.0
#
#
# tracker: (389.0, 315.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 851.0
#
#
# tracker: (403.0, 324.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 874.0
#
#
# tracker: (417.0, 334.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 898.0
#
#
# tracker: (412.0, 330.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 889.0
#
#
# tracker: (419.0, 340.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 906.0
#
#
# tracker: (431.0, 357.0, 37.0, 110.0)
# detector: (432, 343, 102, 107)
# Detector: 984
# Tracker: 935.0
#
#
# tracker: (427.0, 358.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 932.0
#
#
# tracker: (436.0, 368.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 951.0
#
#
# tracker: (450.0, 380.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 977.0
#
#
# tracker: (460.0, 391.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 998.0
#
#
# tracker: (474.0, 395.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1016.0
#
#
# tracker: (488.0, 400.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1035.0
#
#
# tracker: (493.0, 407.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1047.0
#
#
# tracker: (489.0, 418.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1054.0
#
#
# tracker: (477.0, 426.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1050.0
#
#
# tracker: (471.0, 428.0, 37.0, 110.0)
# detector: (427, 394, 131, 122)
# Detector: 1074
# Tracker: 1046.0
#
#
# tracker: (466.0, 415.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1028.0
#
#
# tracker: (468.0, 421.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1036.0
#
#
# tracker: (475.0, 426.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1048.0
#
#
# tracker: (460.0, 426.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1033.0
# tracker: (445.0, 420.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1012.0
#
#
# tracker: (459.0, 423.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1029.0
#
#
# tracker: (452.0, 428.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1027.0
#
#
# tracker: (456.0, 421.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1024.0
#
#
# tracker: (459.0, 423.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1029.0
#
#
# tracker: (468.0, 410.0, 37.0, 110.0)
# detector: (401, 380, 140, 124)
# Detector: 1045
# Tracker: 1025.0
#
#
# tracker: (478.0, 408.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1033.0
#
#
# tracker: (476.0, 401.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1024.0
#
#
# tracker: (477.0, 398.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1022.0
#
#
# tracker: (491.0, 382.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1020.0
#
#
# tracker: (480.0, 388.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1015.0
#
#
# tracker: (494.0, 382.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1023.0
#
#
# tracker: (506.0, 380.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1033.0
#
#
# tracker: (518.0, 383.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1048.0
#
#
# tracker: (532.0, 385.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1064.0
#
#
# tracker: (525.0, 391.0, 37.0, 110.0)
# detector: (464, 337, 149, 151)
# Detector: 1101
# Tracker: 1063.0
#
#
# tracker: (535.0, 398.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1080.0
#
#
# tracker: (545.0, 398.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1090.0
#
#
# tracker: (537.0, 400.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1084.0
#
#
# tracker: (524.0, 395.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1066.0
#
#
# tracker: (524.0, 397.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1068.0
#
#
# tracker: (533.0, 404.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1084.0
#
#
# tracker: (542.0, 416.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1105.0
#
#
# tracker: (542.0, 416.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1105.0
#
#
# tracker: (545.0, 421.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1113.0
#
#
# tracker: (544.0, 420.0, 37.0, 110.0)
# detector: (505, 369, 159, 152)
# Detector: 1185
# Tracker: 1111.0
#
#
# tracker: (536.0, 422.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1105.0
#
#
# tracker: (530.0, 429.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1106.0
#
#
# tracker: (515.0, 430.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1092.0
#
#
# tracker: (503.0, 431.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1081.0
#
#
# tracker: (489.0, 431.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1067.0
#
#
# tracker: (479.0, 431.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1057.0
#
#
# tracker: (476.0, 388.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1011.0
#
#
# tracker: (467.0, 407.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1021.0
#
#
# tracker: (452.0, 373.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 972.0
#
#
# tracker: (440.0, 413.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1000.0
#
#
# tracker: (431.0, 401.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 979.0
#
#
# tracker: (439.0, 391.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 977.0
#
#
# tracker: (426.0, 369.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 942.0
#
#
# tracker: (421.0, 366.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 934.0
#
#
# tracker: (412.0, 402.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 961.0
#
#
# tracker: (402.0, 426.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 975.0
#
#
# tracker: (395.0, 382.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 924.0
#
#
# tracker: (406.0, 420.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 973.0
#
#
# tracker: (391.0, 376.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 914.0
#
#
# tracker: (405.0, 387.0, 37.0, 110.0)
# detector: (175, 391, 182, 153)
# Detector: 901
# Tracker: -4
#
#
# tracker: (390.0, 343.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 880.0
#
#
# tracker: (378.0, 347.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 872.0
#
#
# tracker: (366.0, 354.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 867.0
#
#
# tracker: (359.0, 355.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 861.0
#
#
# tracker: (356.0, 356.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 859.0
#
#
# tracker: (341.0, 312.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 800.0
#
#
# tracker: (355.0, 305.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 807.0
#
#
# tracker: (359.0, 290.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 796.0
#
#
# tracker: (364.0, 268.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 779.0
#
#
# tracker: (368.0, 248.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (374.0, 231.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 752.0
#
#
# tracker: (375.0, 214.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 736.0
#
#
# tracker: (381.0, 198.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 726.0
#
#
# tracker: (378.0, 156.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 681.0
#
#
# tracker: (376.0, 126.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 649.0
#
#
# tracker: (361.0, 82.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 590.0
#
#
# tracker: (347.0, 70.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 564.0
#
#
# tracker: (340.0, 57.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 544.0
#
#
# tracker: (327.0, 30.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 504.0
#
#
# tracker: (326.0, 26.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 499.0
#
#
# tracker: (332.0, 23.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 502.0
#
#
# tracker: (337.0, 20.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 504.0
#
#
# tracker: (342.0, 56.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 545.0
#
#
# tracker: (327.0, 67.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 541.0
#
#
# tracker: (317.0, 93.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 557.0
#
#
# tracker: (302.0, 130.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 579.0
#
#
# tracker: (287.0, 86.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 520.0
#
#
# tracker: (272.0, 42.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 461.0
#
#
# tracker: (261.0, 15.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 423.0
#
#
# tracker: (248.0, 40.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 435.0
#
#
# tracker: (259.0, 15.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 421.0
#
#
# tracker: (245.0, 62.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 454.0
#
#
# tracker: (256.0, 66.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 469.0
#
#
# tracker: (270.0, 67.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 484.0
#
#
# tracker: (255.0, 23.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 425.0
#
#
# tracker: (244.0, 86.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 477.0
#
#
# tracker: (248.0, 57.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 452.0
#
#
# tracker: (251.0, 32.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 430.0
#
#
# tracker: (256.0, 21.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 424.0
#
#
# tracker: (250.0, 8.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 405.0
#
#
# tracker: (251.0, 3.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 401.0
#
#
# tracker: (262.0, 8.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 417.0
#
#
# tracker: (266.0, 7.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 420.0
#
#
# tracker: (255.0, 6.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 408.0
#
#
# tracker: (240.0, 7.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 394.0
# tracker: (225.0, 0.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 372.0
#
#
# tracker: (210.0, 0.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 357.0
#
#
# tracker: (217.0, 56.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 420.0
#
#
# tracker: (205.0, 19.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 371.0
#
#
# tracker: (211.0, 64.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 422.0
#
#
# tracker: (196.0, 20.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 363.0
#
#
# tracker: (205.0, 17.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 369.0
#
#
# tracker: (211.0, 26.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 384.0
#
#
# tracker: (214.0, 47.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 408.0
#
#
# tracker: (214.0, 63.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 424.0
#
#
# tracker: (222.0, 98.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 467.0
#
#
# tracker: (207.0, 54.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 408.0
#
#
# tracker: (207.0, 92.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 446.0
#
#
# tracker: (219.0, 99.0, 37.0, 110.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 465.0
#
#
# tracker: (227.0, 108.0, 37.0, 110.0)
# detector: (95, 219, 162, 165)
# True True True True
# Detector: 641
# Tracker: 482.0
#
#
# tracker: (136.0, 227.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 690.0
#
#
# tracker: (173.0, 237.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 737.0
#
#
# tracker: (208.0, 247.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 782.0
#
#
# tracker: (245.0, 259.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 831.0
#
#
# tracker: (272.0, 269.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 868.0
#
#
# tracker: (297.0, 283.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 907.0
#
#
# tracker: (308.0, 291.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 926.0
#
#
# tracker: (325.0, 297.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 949.0
#
#
# tracker: (340.0, 301.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 968.0
#
#
# tracker: (355.0, 309.0, 162.0, 165.0)
# detector: (350, 296, 179, 179)
# Detector: 1004
# Tracker: 991.0
#
#
# tracker: (372.0, 309.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1008.0
#
#
# tracker: (389.0, 323.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1039.0
#
#
# tracker: (396.0, 325.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1048.0
#
#
# tracker: (413.0, 333.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1073.0
#
#
# tracker: (434.0, 341.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1102.0
#
#
# tracker: (439.0, 347.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1113.0
#
#
# tracker: (446.0, 355.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1128.0
#
#
# tracker: (453.0, 359.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1139.0
#
#
# tracker: (466.0, 363.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1156.0
#
#
# tracker: (455.0, 363.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1145.0
#
#
# tracker: (456.0, 371.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1154.0
#
#
# tracker: (455.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1157.0
#
#
# tracker: (456.0, 371.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1154.0
#
#
# tracker: (453.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1155.0
#
#
# tracker: (452.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1154.0
#
#
# tracker: (445.0, 369.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1141.0
#
#
# tracker: (458.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1160.0
#
#
# tracker: (465.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1167.0
#
#
# tracker: (470.0, 373.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1170.0
#
#
# tracker: (473.0, 375.0, 162.0, 165.0)
# detector: (471, 379, 183, 159)
# Detector: 1192
# Tracker: 1175.0
#
#
# tracker: (480.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1182.0
#
#
# tracker: (483.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1185.0
#
#
# tracker: (494.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1196.0
#
#
# tracker: (503.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1205.0
#
#
# tracker: (512.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1214.0
#
#
# tracker: (521.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1223.0
#
#
# tracker: (528.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1230.0
#
#
# tracker: (535.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1237.0
#
#
# tracker: (544.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1246.0
#
#
# tracker: (553.0, 375.0, 162.0, 165.0)
# detector: (567, 385, 181, 157)
# Detector: 1290
# Tracker: 1255.0
#
#
# tracker: (560.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1262.0
#
#
# tracker: (567.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1269.0
#
#
# tracker: (574.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1276.0
#
#
# tracker: (579.0, 375.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1281.0
#
#
# tracker: (586.0, 369.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1282.0
#
#
# tracker: (589.0, 365.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1281.0
#
#
# tracker: (592.0, 361.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1280.0
#
#
# tracker: (595.0, 357.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1279.0
#
#
# tracker: (600.0, 357.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1284.0
#
#
# tracker: (601.0, 349.0, 162.0, 165.0)
# detector: (615, 357, 179, 177)
# Detector: 1328
# Tracker: 1277.0
#
#
# tracker: (604.0, 347.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1278.0
#
#
# tracker: (609.0, 343.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1279.0
#
#
# tracker: (612.0, 327.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1266.0
#
#
# tracker: (615.0, 325.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1267.0
#
#
# tracker: (614.0, 311.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1252.0
#
#
# tracker: (617.0, 303.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1247.0
#
#
# tracker: (618.0, 295.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1240.0
#
#
# tracker: (619.0, 285.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1231.0
#
#
# tracker: (616.0, 277.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1220.0
#
#
# tracker: (623.0, 281.0, 162.0, 165.0)
# detector: (637, 293, 177, 168)
# Detector: 1275
# Tracker: 1231.0
#
#
# tracker: (632.0, 275.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1234.0
#
#
# tracker: (639.0, 275.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1241.0
#
#
# tracker: (646.0, 283.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1256.0
#
#
# tracker: (651.0, 269.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1247.0
#
#
# tracker: (654.0, 255.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1236.0
#
#
# tracker: (659.0, 237.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1223.0
#
#
# tracker: (664.0, 225.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1216.0
#
#
# tracker: (669.0, 215.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1211.0
#
#
# tracker: (674.0, 207.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1208.0
#
#
# tracker: (673.0, 195.0, 162.0, 165.0)
# detector: (688, 216, 160, 151)
# Detector: 1215
# Tracker: 1195.0
#
#
# tracker: (678.0, 191.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1196.0
#
#
# tracker: (677.0, 181.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1185.0
#
#
# tracker: (680.0, 177.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1184.0
# tracker: (683.0, 163.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1173.0
#
#
# tracker: (686.0, 151.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1164.0
#
#
# tracker: (689.0, 137.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1153.0
#
#
# tracker: (692.0, 125.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1144.0
#
#
# tracker: (693.0, 115.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1135.0
#
#
# tracker: (696.0, 109.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1132.0
#
#
# tracker: (697.0, 103.0, 162.0, 165.0)
# detector: (709, 119, 146, 146)
# Detector: 1120
# Tracker: 1127.0
#
#
# tracker: (698.0, 97.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1122.0
#
#
# tracker: (695.0, 79.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1101.0
#
#
# tracker: (694.0, 69.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1090.0
#
#
# tracker: (693.0, 59.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1079.0
#
#
# tracker: (688.0, 56.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1071.0
#
#
# tracker: (663.0, 46.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1036.0
#
#
# tracker: (636.0, 40.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1003.0
#
#
# tracker: (611.0, 40.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 978.0
#
#
# tracker: (584.0, 36.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 947.0
#
#
# tracker: (555.0, 36.0, 162.0, 165.0)
# detector: (561, 62, 140, 122)
# Detector: 885
# Tracker: 918.0
#
#
# tracker: (524.0, 38.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 889.0
#
#
# tracker: (497.0, 46.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 870.0
#
#
# tracker: (468.0, 52.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 847.0
#
#
# tracker: (441.0, 58.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 826.0
#
#
# tracker: (416.0, 68.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 811.0
#
#
# tracker: (391.0, 80.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 798.0
#
#
# tracker: (366.0, 94.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 787.0
#
#
# tracker: (345.0, 108.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 780.0
#
#
# tracker: (328.0, 116.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 771.0
#
#
# tracker: (311.0, 124.0, 162.0, 165.0)
# detector: (323, 158, 124, 116)
# Detector: 721
# Tracker: 762.0
#
#
# tracker: (296.0, 132.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 755.0
#
#
# tracker: (279.0, 136.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 742.0
#
#
# tracker: (264.0, 140.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 731.0
#
#
# tracker: (239.0, 146.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 712.0
#
#
# tracker: (214.0, 152.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 693.0
#
#
# tracker: (191.0, 156.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 674.0
#
#
# tracker: (164.0, 162.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 653.0
#
#
# tracker: (143.0, 168.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 638.0
#
#
# tracker: (122.0, 176.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 625.0
#
#
# tracker: (97.0, 184.0, 162.0, 165.0)
# detector: (104, 217, 135, 119)
# Detector: 575
# Tracker: 608.0
#
#
# tracker: (74.0, 192.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 593.0
#
#
# tracker: (55.0, 202.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 584.0
#
#
# tracker: (34.0, 206.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 567.0
#
#
# tracker: (16.0, 206.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 549.0
#
#
# tracker: (0.0, 208.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 535.0
#
#
# tracker: (0.0, 142.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 469.0
#
#
# tracker: (0.0, 76.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 403.0
#
#
# tracker: (0.0, 70.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 397.0
#
#
# tracker: (4.0, 64.0, 162.0, 165.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 395.0
#
#
# tracker: (10.0, 60.0, 162.0, 165.0)
# detector: (1, 255, 79, 125)
# True True True True
# Detector: 460
# Tracker: 397.0
#
#
# tracker: (0.0, 259.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 463.0
#
#
# tracker: (0.0, 251.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 455.0
#
#
# tracker: (5.0, 251.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 460.0
#
#
# tracker: (14.0, 255.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 473.0
#
#
# tracker: (27.0, 253.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 484.0
#
#
# tracker: (42.0, 253.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 499.0
#
#
# tracker: (60.0, 250.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 514.0
#
#
# tracker: (85.0, 241.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 530.0
#
#
# tracker: (106.0, 234.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 544.0
#
#
# tracker: (134.0, 221.0, 79.0, 125.0)
# detector: (83, 222, 126, 127)
# Detector: 558
# Tracker: 559.0
#
#
# tracker: (160.0, 216.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 580.0
#
#
# tracker: (186.0, 206.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 596.0
#
#
# tracker: (217.0, 199.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 620.0
#
#
# tracker: (238.0, 190.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 632.0
#
#
# tracker: (264.0, 184.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 652.0
#
#
# tracker: (288.0, 178.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 670.0
#
#
# tracker: (311.0, 174.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 689.0
#
#
# tracker: (337.0, 169.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 710.0
#
#
# tracker: (358.0, 167.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 729.0
#
#
# tracker: (378.0, 165.0, 79.0, 125.0)
# detector: (342, 164, 114, 119)
# Detector: 739
# Tracker: 747.0
#
#
# tracker: (397.0, 162.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (416.0, 159.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 779.0
#
#
# tracker: (429.0, 154.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 787.0
#
#
# tracker: (442.0, 153.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 799.0
#
#
# tracker: (451.0, 149.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 804.0
#
#
# tracker: (461.0, 145.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 810.0
#
#
# tracker: (470.0, 141.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 815.0
#
#
# tracker: (476.0, 138.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 818.0
#
#
# tracker: (480.0, 135.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 819.0
#
#
# tracker: (484.0, 133.0, 79.0, 125.0)
# detector: (448, 141, 118, 105)
# Detector: 812
# Tracker: 821.0
#
#
# tracker: (484.0, 129.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 817.0
#
#
# tracker: (482.0, 125.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 811.0
#
#
# tracker: (477.0, 121.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 802.0
#
#
# tracker: (474.0, 117.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 795.0
#
#
# tracker: (478.0, 119.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 801.0
#
#
# tracker: (489.0, 123.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 816.0
#
#
# tracker: (496.0, 126.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 826.0
#
#
# tracker: (506.0, 128.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 838.0
#
#
# tracker: (515.0, 130.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 849.0
#
#
# tracker: (524.0, 132.0, 79.0, 125.0)
# detector: (492, 140, 115, 103)
# Detector: 850
# Tracker: 860.0
#
#
# tracker: (536.0, 137.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 877.0
#
#
# tracker: (544.0, 144.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 892.0
# tracker: (555.0, 146.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 905.0
#
#
# tracker: (562.0, 146.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 912.0
#
#
# tracker: (568.0, 146.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 918.0
#
#
# tracker: (574.0, 147.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 925.0
#
#
# tracker: (579.0, 151.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 934.0
#
#
# tracker: (586.0, 154.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 944.0
#
#
# tracker: (589.0, 158.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 951.0
#
#
# tracker: (594.0, 163.0, 79.0, 125.0)
# detector: (561, 170, 110, 110)
# Detector: 951
# Tracker: 961.0
#
#
# tracker: (596.0, 166.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 966.0
#
#
# tracker: (597.0, 168.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 969.0
#
#
# tracker: (596.0, 171.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 971.0
#
#
# tracker: (594.0, 176.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 974.0
#
#
# tracker: (590.0, 179.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 973.0
#
#
# tracker: (583.0, 185.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 972.0
#
#
# tracker: (558.0, 187.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 949.0
#
#
# tracker: (548.0, 189.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 941.0
#
#
# tracker: (516.0, 236.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 956.0
#
#
# tracker: (520.0, 220.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 944.0
#
#
# tracker: (533.0, 206.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 943.0
#
#
# tracker: (564.0, 194.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 962.0
#
#
# tracker: (595.0, 189.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 988.0
#
#
# tracker: (626.0, 187.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1017.0
#
#
# tracker: (656.0, 178.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1038.0
#
#
# tracker: (687.0, 180.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1071.0
#
#
# tracker: (696.0, 178.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1078.0
#
#
# tracker: (706.0, 171.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1081.0
#
#
# tracker: (718.0, 164.0, 79.0, 125.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 1086.0
#
#
# tracker: (727.0, 158.0, 79.0, 125.0)
# detector: (240, 192, 98, 95)
# True True True True
# Detector: 625
# Tracker: 1089.0
#
#
# tracker: (222.0, 206.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 621.0
#
#
# tracker: (212.0, 198.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 603.0
#
#
# tracker: (210.0, 191.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 594.0
#
#
# tracker: (198.0, 197.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 588.0
#
#
# tracker: (200.0, 195.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 588.0
#
#
# tracker: (196.0, 195.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 584.0
#
#
# tracker: (200.0, 192.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 585.0
#
#
# tracker: (191.0, 202.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 586.0
#
#
# tracker: (195.0, 201.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 589.0
#
#
# tracker: (190.0, 207.0, 98.0, 95.0)
# detector: (195, 204, 119, 98)
# Detector: 616
# Tracker: 590.0
#
#
# tracker: (197.0, 202.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 592.0
#
#
# tracker: (198.0, 206.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (202.0, 210.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 605.0
#
#
# tracker: (208.0, 213.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 614.0
#
#
# tracker: (212.0, 217.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 622.0
#
#
# tracker: (221.0, 215.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 629.0
#
#
# tracker: (229.0, 214.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 636.0
#
#
# tracker: (238.0, 214.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 645.0
#
#
# tracker: (252.0, 213.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 658.0
#
#
# tracker: (259.0, 215.0, 98.0, 95.0)
# detector: (265, 220, 104, 93)
# Detector: 682
# Tracker: 667.0
#
#
# tracker: (269.0, 216.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 678.0
#
#
# tracker: (278.0, 215.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 686.0
#
#
# tracker: (287.0, 212.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 692.0
#
#
# tracker: (296.0, 209.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 698.0
#
#
# tracker: (306.0, 207.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 706.0
#
#
# tracker: (316.0, 205.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 714.0
#
#
# tracker: (325.0, 204.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 722.0
#
#
# tracker: (336.0, 202.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 731.0
#
#
# tracker: (345.0, 202.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 740.0
#
#
# tracker: (352.0, 203.0, 98.0, 95.0)
# detector: (355, 205, 105, 97)
# Detector: 762
# Tracker: 748.0
#
#
# tracker: (359.0, 205.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 757.0
#
#
# tracker: (364.0, 206.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (366.0, 208.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 767.0
#
#
# tracker: (366.0, 208.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 767.0
#
#
# tracker: (364.0, 209.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 766.0
#
#
# tracker: (362.0, 209.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 764.0
#
#
# tracker: (360.0, 211.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 764.0
#
#
# tracker: (358.0, 212.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (357.0, 213.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (355.0, 214.0, 98.0, 95.0)
# detector: (358, 220, 100, 91)
# Detector: 769
# Tracker: 762.0
#
#
# tracker: (350.0, 217.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 760.0
#
#
# tracker: (349.0, 217.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 759.0
#
#
# tracker: (348.0, 222.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 763.0
#
#
# tracker: (349.0, 223.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 765.0
#
#
# tracker: (349.0, 223.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 765.0
#
#
# tracker: (349.0, 225.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 767.0
#
#
# tracker: (349.0, 226.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 768.0
#
#
# tracker: (350.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 771.0
#
#
# tracker: (351.0, 231.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 775.0
#
#
# tracker: (352.0, 230.0, 98.0, 95.0)
# detector: (352, 235, 101, 89)
# Detector: 777
# Tracker: 775.0
#
#
# tracker: (351.0, 229.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 773.0
#
#
# tracker: (354.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 775.0
#
#
# tracker: (356.0, 229.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 778.0
#
#
# tracker: (358.0, 230.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 781.0
#
#
# tracker: (361.0, 231.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 785.0
#
#
# tracker: (364.0, 231.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 788.0
#
#
# tracker: (370.0, 229.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 792.0
#
#
# tracker: (374.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 795.0
#
#
# tracker: (379.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 800.0
#
#
# tracker: (383.0, 227.0, 98.0, 95.0)
# detector: (387, 233, 95, 89)
# Detector: 804
# Tracker: 803.0
#
#
# tracker: (388.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 809.0
#
#
# tracker: (393.0, 229.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 815.0
#
#
# tracker: (396.0, 233.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 822.0
# tracker: (400.0, 235.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 828.0
#
#
# tracker: (403.0, 235.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 831.0
#
#
# tracker: (406.0, 233.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 832.0
#
#
# tracker: (407.0, 233.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 833.0
#
#
# tracker: (389.0, 237.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 819.0
#
#
# tracker: (370.0, 242.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 805.0
#
#
# tracker: (353.0, 244.0, 98.0, 95.0)
# detector: (358, 247, 100, 92)
# Detector: 797
# Tracker: 790.0
#
#
# tracker: (339.0, 242.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 774.0
#
#
# tracker: (323.0, 242.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 758.0
#
#
# tracker: (308.0, 242.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 743.0
#
#
# tracker: (291.0, 244.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 728.0
#
#
# tracker: (275.0, 246.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 714.0
#
#
# tracker: (260.0, 249.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 702.0
#
#
# tracker: (243.0, 250.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 686.0
#
#
# tracker: (227.0, 257.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 677.0
#
#
# tracker: (215.0, 256.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 664.0
#
#
# tracker: (206.0, 255.0, 98.0, 95.0)
# detector: (202, 262, 108, 90)
# Detector: 662
# Tracker: 654.0
#
#
# tracker: (195.0, 255.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 643.0
#
#
# tracker: (187.0, 254.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 634.0
#
#
# tracker: (179.0, 255.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 627.0
#
#
# tracker: (169.0, 255.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 617.0
#
#
# tracker: (160.0, 261.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 614.0
#
#
# tracker: (151.0, 262.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 606.0
#
#
# tracker: (144.0, 268.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 605.0
#
#
# tracker: (138.0, 270.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 601.0
#
#
# tracker: (133.0, 272.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 598.0
#
#
# tracker: (130.0, 269.0, 98.0, 95.0)
# detector: (137, 271, 101, 92)
# Detector: 601
# Tracker: 592.0
#
#
# tracker: (129.0, 265.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 587.0
#
#
# tracker: (129.0, 264.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 586.0
#
#
# tracker: (130.0, 264.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 587.0
#
#
# tracker: (132.0, 264.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 589.0
#
#
# tracker: (134.0, 265.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 592.0
#
#
# tracker: (138.0, 263.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 594.0
#
#
# tracker: (141.0, 262.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 596.0
#
#
# tracker: (143.0, 259.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 595.0
#
#
# tracker: (147.0, 255.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 595.0
#
#
# tracker: (150.0, 253.0, 98.0, 95.0)
# detector: (157, 260, 96, 83)
# Detector: 596
# Tracker: 596.0
#
#
# tracker: (153.0, 252.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 598.0
#
#
# tracker: (158.0, 250.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 601.0
#
#
# tracker: (162.0, 248.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 603.0
#
#
# tracker: (162.0, 244.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 599.0
#
#
# tracker: (165.0, 245.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 603.0
#
#
# tracker: (165.0, 243.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 601.0
#
#
# tracker: (166.0, 240.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 599.0
#
#
# tracker: (166.0, 240.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 599.0
#
#
# tracker: (169.0, 239.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 601.0
#
#
# tracker: (169.0, 236.0, 98.0, 95.0)
# detector: (170, 244, 95, 81)
# Detector: 590
# Tracker: 598.0
#
#
# tracker: (170.0, 230.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 593.0
#
#
# tracker: (171.0, 232.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 596.0
#
#
# tracker: (172.0, 227.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 592.0
#
#
# tracker: (175.0, 229.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (176.0, 228.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (178.0, 226.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (181.0, 218.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 592.0
#
#
# tracker: (184.0, 218.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 595.0
#
#
# tracker: (183.0, 220.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 596.0
#
#
# tracker: (221.0, 252.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 666.0
#
#
# tracker: (217.0, 264.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 674.0
#
#
# tracker: (237.0, 264.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 694.0
#
#
# tracker: (251.0, 258.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 702.0
#
#
# tracker: (277.0, 253.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 723.0
#
#
# tracker: (294.0, 249.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 736.0
#
#
# tracker: (309.0, 247.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 749.0
#
#
# tracker: (326.0, 242.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 761.0
#
#
# tracker: (344.0, 239.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 776.0
#
#
# tracker: (361.0, 233.0, 98.0, 95.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 787.0
#
#
# tracker: (377.0, 227.0, 98.0, 95.0)
# detector: (207, 212, 94, 80)
# True True True True
# Detector: 593
# Tracker: 797.0
#
#
# tracker: (209.0, 209.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 592.0
#
#
# tracker: (214.0, 206.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 594.0
#
#
# tracker: (217.0, 206.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (223.0, 207.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 604.0
#
#
# tracker: (225.0, 192.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 591.0
#
#
# tracker: (231.0, 197.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 602.0
#
#
# tracker: (235.0, 188.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 597.0
#
#
# tracker: (242.0, 193.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 609.0
#
#
# tracker: (249.0, 193.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 616.0
#
#
# tracker: (252.0, 189.0, 94.0, 80.0)
# detector: (257, 193, 84, 78)
# Detector: 612
# Tracker: 615.0
#
#
# tracker: (255.0, 188.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 617.0
#
#
# tracker: (261.0, 192.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 627.0
#
#
# tracker: (259.0, 190.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 623.0
#
#
# tracker: (258.0, 188.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 620.0
#
#
# tracker: (256.0, 189.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 619.0
#
#
# tracker: (254.0, 185.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 613.0
#
#
# tracker: (251.0, 185.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 610.0
#
#
# tracker: (250.0, 186.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 610.0
#
#
# tracker: (247.0, 184.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 605.0
#
#
# tracker: (248.0, 181.0, 94.0, 80.0)
# detector: (260, 191, 76, 68)
# Detector: 595
# Tracker: 603.0
#
#
# tracker: (248.0, 179.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 601.0
#
#
# tracker: (246.0, 175.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 595.0
#
#
# tracker: (246.0, 170.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 590.0
# tracker: (247.0, 170.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 591.0
#
#
# tracker: (247.0, 169.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 590.0
#
#
# tracker: (245.0, 168.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 587.0
#
#
# tracker: (245.0, 164.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 583.0
#
#
# tracker: (243.0, 159.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 576.0
#
#
# tracker: (242.0, 157.0, 94.0, 80.0)
# detector: (-1, -1, -1, -1)
# Detector: -4
# Tracker: 573.0
#
#
# tracker: (242.0, 156.0, 94.0, 80.0)
# detector: (255, 166, 71, 70)
# Detector: 562
# Tracker: 572.0
